# %%
import pandas as pd
filepath1="/home/maya/Downloads/file1.xlsx"
filepath2="/home/maya/Downloads/file2.xlsx"
df1=pd.read_excel(filepath1)
df2=pd.read_excel(filepath2)

# %%
df1.head(5)
# Out:
#        SYMBOL SERIES      OPEN      HIGH      LOW     CLOSE      LAST
# 0   20MICRONS     EQ     29.85     30.90     29.0     30.10     30.85
# 1  21STCENMGM     EQ     10.10     10.25     10.1     10.25     10.25
# 2  3IINFOTECH     EQ      2.30      2.40      2.3      2.40      2.35
# 3     3MINDIA     EQ  20940.00  21099.00  20550.0  20579.50  20550.00
# 4   579GS2030     GS     99.00     99.00     98.1     98.10     98.10

# %%
df2.head(5)
# Out:
#        SYMBOL SERIES      OPEN      HIGH       LOW
# 0   20MICRONS     EQ     30.70     30.70     29.70
# 1  21STCENMGM     EQ     10.70     10.70     10.35
# 2  3IINFOTECH     EQ      2.45      2.50      2.40
# 3     3MINDIA     EQ  21360.00  21899.00  21100.00
# 4      5PAISA     EQ    381.30    399.85    381.30

# %%
df1["SYMBOL"].isin(df2["SYMBOL"])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27     True
# 28    False
# Name: SYMBOL, dtype: bool

# %% [markdown]
# # filtered excel sheet separately

# %%
filterd_sheet=pd.read_excel(filepath1,sheet_name=1)
filterd_sheet
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST
# 0    20MICRONS     EQ     30.40     31.35     29.50     30.35     30.30
# 1   21STCENMGM     EQ     10.60     10.60     10.45     10.55     10.55
# 2   3IINFOTECH     EQ      2.45      2.50      2.35      2.45      2.45
# 3      3MINDIA     EQ  21301.00  21649.95  21225.00  21512.20  21500.00
# 4       3PLAND     EQ      8.05      8.05      8.05      8.05      8.05
# 5       5PAISA     EQ    401.35    401.35    401.35    401.35    401.35
# 6    619GS2034     GS     99.50     99.50     99.50     99.50     99.50
# 7      63MOONS     BE     70.85     71.75     69.10     70.45     71.00
# 8    657GS2033     GS     95.00     95.00     95.00     95.00     95.00
# 9    700GS2021     GS     94.40     94.40     94.40     94.40     94.40
# 10   716GS2050     GS    111.70    111.70    111.70    111.70    111.70
# 11   719GS2060     GS    114.64    114.65    114.64    114.65    114.65
# ...

# %%
df1.keys()
# Out:
# Index(['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST'], dtype='object')

# %%
all_dfs=[df1,df2]
combined_dfs=pd.concat(all_dfs)
combined_dfs
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST
# 0    20MICRONS     EQ     29.85     30.90     29.00     30.10     30.85
# 1   21STCENMGM     EQ     10.10     10.25     10.10     10.25     10.25
# 2   3IINFOTECH     EQ      2.30      2.40      2.30      2.40      2.35
# 3      3MINDIA     EQ  20940.00  21099.00  20550.00  20579.50  20550.00
# 4    579GS2030     GS     99.00     99.00     98.10     98.10     98.10
# 5       5PAISA     EQ    316.05    343.25    316.05    343.25    343.25
# 6      63MOONS     BE     68.00     68.95     66.00     68.05     68.00
# 7    706GS2046     GS    102.63    105.00    102.63    103.00    103.00
# 8    716GS2050     GS    110.00    110.00    110.00    110.00    110.00
# 9    719GS2060     GS    115.00    115.00    115.00    115.00    115.00
# 10   757GS2033     GS    111.00    111.00    111.00    111.00    111.00
# 11   813GS2045     GS    122.00    122.00    122.00    122.00    122.00
# ...

# %% [markdown]
# # Saving to new Excel file

# %%
combined_dfs.to_excel("Alldfsvalues.xlsx",index=False)

# %% [markdown]
# # Iteration of Multiple Excel sheets

# %%
import os,collections
#odict_keys(["Sheet1","Sheet2"])
newfile=[]
NoOfSheets=4
for i in range(NoOfSheets):
    data1=pd.read_excel(filepath1,header=None)
    newfile.append(data1)

# %%
new_df=df1.loc[(df1["SYMBOL"].isin(df2["SYMBOL"]))&(df1["HIGH"]>399)]
new_df.head(5)
# Out:
#         SYMBOL SERIES     OPEN     HIGH       LOW     CLOSE      LAST
# 3      3MINDIA     EQ  20940.0  21099.0  20550.00  20579.50  20550.00
# 14  AARTIDRUGS     EQ   1750.0   1751.5   1701.00   1732.75   1726.50
# 15    AARTIIND     EQ   1027.0   1050.0    985.05   1044.90   1044.00
# 19       AAVAS     EQ   1418.8   1419.0   1352.05   1365.25   1352.05
# 21         ABB     EQ    882.6    909.7    881.60    905.30    905.95

# %% [markdown]
# # removing special characters

# %%
df1["SYMBOL"]=df1["SYMBOL"].str.replace(r'\W',"")
df1.head(5)
# Out:
#        SYMBOL SERIES      OPEN      HIGH      LOW     CLOSE      LAST
# 0   20MICRONS     EQ     29.85     30.90     29.0     30.10     30.85
# 1  21STCENMGM     EQ     10.10     10.25     10.1     10.25     10.25
# 2  3IINFOTECH     EQ      2.30      2.40      2.3      2.40      2.35
# 3     3MINDIA     EQ  20940.00  21099.00  20550.0  20579.50  20550.00
# 4   579GS2030     GS     99.00     99.00     98.1     98.10     98.10

# %%
df1.drop_duplicates()
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST
# 0    20MICRONS     EQ     29.85     30.90     29.00     30.10     30.85
# 1   21STCENMGM     EQ     10.10     10.25     10.10     10.25     10.25
# 2   3IINFOTECH     EQ      2.30      2.40      2.30      2.40      2.35
# 3      3MINDIA     EQ  20940.00  21099.00  20550.00  20579.50  20550.00
# 4    579GS2030     GS     99.00     99.00     98.10     98.10     98.10
# 5       5PAISA     EQ    316.05    343.25    316.05    343.25    343.25
# 6      63MOONS     BE     68.00     68.95     66.00     68.05     68.00
# 7    706GS2046     GS    102.63    105.00    102.63    103.00    103.00
# 8    716GS2050     GS    110.00    110.00    110.00    110.00    110.00
# 9    719GS2060     GS    115.00    115.00    115.00    115.00    115.00
# 10   757GS2033     GS    111.00    111.00    111.00    111.00    111.00
# 11   813GS2045     GS    122.00    122.00    122.00    122.00    122.00
# ...

# %%
df1.dropna()
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST
# 0    20MICRONS     EQ     29.85     30.90     29.00     30.10     30.85
# 1   21STCENMGM     EQ     10.10     10.25     10.10     10.25     10.25
# 2   3IINFOTECH     EQ      2.30      2.40      2.30      2.40      2.35
# 3      3MINDIA     EQ  20940.00  21099.00  20550.00  20579.50  20550.00
# 4    579GS2030     GS     99.00     99.00     98.10     98.10     98.10
# 5       5PAISA     EQ    316.05    343.25    316.05    343.25    343.25
# 6      63MOONS     BE     68.00     68.95     66.00     68.05     68.00
# 7    706GS2046     GS    102.63    105.00    102.63    103.00    103.00
# 8    716GS2050     GS    110.00    110.00    110.00    110.00    110.00
# 9    719GS2060     GS    115.00    115.00    115.00    115.00    115.00
# 10   757GS2033     GS    111.00    111.00    111.00    111.00    111.00
# 11   813GS2045     GS    122.00    122.00    122.00    122.00    122.00
# ...

# %%
df2.dropna()
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW
# 0    20MICRONS     EQ     30.70     30.70     29.70
# 1   21STCENMGM     EQ     10.70     10.70     10.35
# 2   3IINFOTECH     EQ      2.45      2.50      2.40
# 3      3MINDIA     EQ  21360.00  21899.00  21100.00
# 4       5PAISA     EQ    381.30    399.85    381.30
# 5    618GS2024     GS    105.45    105.45    105.45
# 6    619GS2034     GS     99.50     99.50     99.50
# 7      63MOONS     BE     70.45     72.00     69.40
# 8    716GS2050     GS    111.70    111.70    111.70
# 9    719GS2060     GS    113.50    113.50    113.04
# 10   762GS2039     GS    110.00    110.00    110.00
# 11   763GS2059     GS    120.68    120.68    120.68
# 12   772GS2049     GS    118.99    119.00    118.99
# 13   772GS2055     GS    111.35    111.35    111.35
# 14   824GS2033     GS    110.00    110.00    110.00
# 15    A2ZINFRA     EQ      4.15      4.30      4.00
# 16      AAKASH     SM     39.50     39.50     39.00
# ...
